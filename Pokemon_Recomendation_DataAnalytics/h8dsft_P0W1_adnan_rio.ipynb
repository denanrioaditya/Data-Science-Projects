# %% [markdown]
# # Graded Challenge 1
# ```txt
# Adnan Rio
# Batch 14
# ```

# %% [markdown]
# ## Description
#
# ### Objective
#
# `Mencari kombinasi Name dengan Type 1 dan Type 2 bertipikal tipe defense `
#
# ### Problem Statement
#
# `Banyak Name dengan Type 1 dan Type 2 yang tidak sesuai`

# %% [markdown]
# ## Working Area

# %% [markdown]
# `` Import Libary ``

# %%
import pandas as pd #   Memanggil library panda kemudian menganti alias pd
import numpy as np #    Memanggil library numpy kemudian menganti alias np
import matplotlib.pyplot as plt #   Memanggil library matplotlib kemudian menganti alias plt

# %% [markdown]
# `` Data overview ``

# %%
df = pd.read_csv('Pokemon.csv') # Memuat data dengan Pandas

# %%
df.head(15) # Melihat data teratas
# Out:
#      #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0    1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1    2                    Ivysaur  Grass  Poison    405  60      62       63
# 2    3                   Venusaur  Grass  Poison    525  80      82       83
# 3    3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4    4                 Charmander   Fire     NaN    309  39      52       43
# 5    5                 Charmeleon   Fire     NaN    405  58      64       58
# 6    6                  Charizard   Fire  Flying    534  78      84       78
# 7    6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8    6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9    7                   Squirtle  Water     NaN    314  44      48       65
# 10   8                  Wartortle  Water     NaN    405  59      63       80
# ...

# %%
df.tail(15) # Melihat data terbawah
# Out:
#        #                 Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 785  711  GourgeistSmall Size    Ghost   Grass    494   55      85      122
# 786  711  GourgeistLarge Size    Ghost   Grass    494   75      95      122
# 787  711  GourgeistSuper Size    Ghost   Grass    494   85     100      122
# 788  712             Bergmite      Ice     NaN    304   55      69       85
# 789  713              Avalugg      Ice     NaN    514   95     117      184
# 790  714               Noibat   Flying  Dragon    245   40      30       35
# 791  715              Noivern   Flying  Dragon    535   85      70       80
# 792  716              Xerneas    Fairy     NaN    680  126     131       95
# 793  717              Yveltal     Dark  Flying    680  126     131       95
# 794  718     Zygarde50% Forme   Dragon  Ground    600  108     100      121
# 795  719              Diancie     Rock   Fairy    600   50     100      150
# ...

# %%
df.sample(15) # Menampilakan 5 data secara acak
# Out:
#        #                   Name    Type 1    Type 2  Total   HP  Attack  \
# 780  710  PumpkabooAverage Size     Ghost     Grass    335   49      66
# 110  102              Exeggcute     Grass   Psychic    325   60      40
# 439  394               Prinplup     Water       NaN    405   64      66
# 166  152              Chikorita     Grass       NaN    318   45      49
# 731  663             Talonflame      Fire    Flying    499   78      81
# 219  204                 Pineco       Bug       NaN    290   50      65
# 361  330                 Flygon    Ground    Dragon    520   80     100
# 186  172                  Pichu  Electric       NaN    205   20      40
# 554  495                  Snivy     Grass       NaN    308   45      45
# 278  257               Blaziken      Fire  Fighting    530   80     120
# 351  321                Wailord     Water       NaN    500  170      90
# 587  528                Swoobat   Psychic    Flying    425   67      57
# ...

# %%
df.info() # Menampilakan informasi , jumlah entries data, jumlah kolom, missing value, tipe data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
df.loc[:8, 'Type 1':'Type 2']
# Out:
#   Type 1  Type 2
# 0  Grass  Poison
# 1  Grass  Poison
# 2  Grass  Poison
# 3  Grass  Poison
# 4   Fire     NaN
# 5   Fire     NaN
# 6   Fire  Flying
# 7   Fire  Dragon
# 8   Fire  Flying

# %%
df['Type 1'].unique() # Menampilakan data pada kolom 'Type 1'
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
df['Type 2'].unique() # Menampilakan data pada kolom 'Type 2'
# Out:
# array(['Poison', nan, 'Flying', 'Dragon', 'Ground', 'Fairy', 'Grass',
#        'Fighting', 'Psychic', 'Steel', 'Ice', 'Rock', 'Dark', 'Water',
#        'Electric', 'Fire', 'Ghost', 'Bug', 'Normal'], dtype=object)

# %%
df.describe().T # Menampilakn statstik dasar data bertipe numerik
# Out:
#             count       mean         std    min     25%    50%     75%    max
# #           800.0  362.81375  208.343798    1.0  184.75  364.5  539.25  721.0
# Total       800.0  435.10250  119.963040  180.0  330.00  450.0  515.00  780.0
# HP          800.0   69.25875   25.534669    1.0   50.00   65.0   80.00  255.0
# Attack      800.0   79.00125   32.457366    5.0   55.00   75.0  100.00  190.0
# Defense     800.0   73.84250   31.183501    5.0   50.00   70.0   90.00  230.0
# Sp. Atk     800.0   72.82000   32.722294   10.0   49.75   65.0   95.00  194.0
# Sp. Def     800.0   71.90250   27.828916   20.0   50.00   70.0   90.00  230.0
# Speed       800.0   68.27750   29.060474    5.0   45.00   65.0   90.00  180.0
# Generation  800.0    3.32375    1.661290    1.0    2.00    3.0    5.00    6.0

# %%
pd.set_option('display.max_columns', None) # None menampilkan semua kolom
pd.set_option('display.max_row', 15) # Menampilkan 15 baris karena teralu banyak

# %% [markdown]
# ```txt
#
# # Missing value
#
#    Langkah - langkah menangani missing values pada dataset adalah
# 1. Mencari nilai kosong pada kolom
# 2. Periksa jumlah kolom yang missing value pada dataset dengan menggunakan perintah
#    df.isnull().sum()
# 3. Kemdian isi dengan mengunakan perintah EDA["Type 2"].fillna(value="-", inplace= True)
# ```

# %%
df.isnull().sum()
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        386
# Total           0
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
EDA = df.copy()

# %%
EDA["Type 2"].fillna(value="-", inplace= True)

# %%
# Missing values menjadi 0
EDA.isnull().sum()

# %%
EDA

# %% [markdown]
# ```txt
# # Manipulating Columns
#     Pada dataset kita dapat mengedit columns
#     Langkah - langkah manipulating columns pada dataset adalah
# 1.  Tentukan columns yang di ubah
# 2.  Setelah itu copy dataset dengan perintah man = df.copy() agar tidak harus mengimport dataset lagi
# ```

# %%
EDA = EDA.rename(columns={
    "Total" : "Power",
    "Type 1" : "Elemen",
    "Type 2" : "Tipe",
    "Sp. Atk" : "SpAttack",
    "Sp. Def" : "SpDefense"
})

# %%
EDA
# Out:
#        #                   Name   Elemen    Tipe  Power  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire       -    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
rename_man = df.copy() # Karena semua column berguna , kita uji coba dengan cara mengopy terlebih dahulu dataset

# %%
rename_man.drop(labels=['Attack', 'Sp. Atk'], axis=1, inplace=True)

# %%
rename_man
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Defense  Sp. Def  \
# 0      1              Bulbasaur    Grass  Poison    318  45       49       65
# 1      2                Ivysaur    Grass  Poison    405  60       63       80
# 2      3               Venusaur    Grass  Poison    525  80       83      100
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80      123      120
# 4      4             Charmander     Fire     NaN    309  39       43       50
# ..   ...                    ...      ...     ...    ...  ..      ...      ...
# 795  719                Diancie     Rock   Fairy    600  50      150      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50      110      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80       60      130
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80       60      130
# 799  721              Volcanion     Fire   Water    600  80      120       90
#
# ...

# %% [markdown]
# ```txt
#    # Data Query
#    Langkah - langkah menggunakan data query values pada dataset adalah mencari data spesifik yang sesuai dengan kriteria yang diingikan
#
# ```

# %%
# Menampilkan Name Legendary dengan urutan Defense tertinggi sampai terendah
EDA.query("Defense > 100 & \
          Legendary == True").sort_values(by='Defense',ascending=False)
# Out:
#        #                   Name   Elemen   Tipe  Power   HP  Attack  Defense  \
# 414  377               Regirock     Rock      -    580   80     100      200
# 424  383  GroudonPrimal Groudon   Ground   Fire    770  100     180      160
# 430  386    DeoxysDefense Forme  Psychic      -    600   50      70      160
# 416  379              Registeel    Steel      -    580   80      75      150
# 795  719                Diancie     Rock  Fairy    600   50     100      150
# ..   ...                    ...      ...    ...    ...  ...     ...      ...
# 264  245                Suicune    Water      -    580  100      75      115
# 543  486              Regigigas   Normal      -    670  110     160      110
# 796  719    DiancieMega Diancie     Rock  Fairy    700   50     160      110
# 542  485                Heatran     Fire  Steel    600   91      90      106
# 538  481                Mesprit  Psychic      -    580   80     105      105
#
# ...

# %%
# Menampilkan Name bukan Legendary dengan urutan Defense tertinggi sampai terendah
EDA.query("Defense > 100 & \
          Legendary == False").sort_values(by='Defense',ascending=False)
# Out:
#        #                 Name Elemen    Tipe  Power  HP  Attack  Defense  \
# 333  306    AggronMega Aggron  Steel       -    630  70     140      230
# 230  213              Shuckle    Bug    Rock    505  20      10      230
# 224  208  SteelixMega Steelix  Steel  Ground    610  75     125      230
# 223  208              Steelix  Steel  Ground    510  75      85      200
# 789  713              Avalugg    Ice       -    514  95     117      184
# ..   ...                  ...    ...     ...    ...  ..     ...      ...
# 650  589           Escavalier    Bug   Steel    495  70     135      105
# 584  525              Boldore   Rock       -    390  70     105      105
# 403  368             Gorebyss  Water       -    485  55      84      105
# 625  564             Tirtouga  Water    Rock    355  54      78      103
# 463  416            Vespiquen    Bug  Flying    474  70      80      102
#
#      SpAttack  SpDefense  Speed  Generation  Legendary
# ...

# %%
# Menampilkan Name dengan HP diatas 100, Defense diatas 100 dan SpDefense diatas 100
EDA.query("HP >= 100 & \
              Defense >= 100 &\
              SpDefense >= 100").sort_values(by='HP',ascending=False)
# Out:
#        #                   Name   Elemen      Tipe  Power   HP  Attack  \
# 545  487   GiratinaOrigin Forme    Ghost    Dragon    680  150     120
# 544  487  GiratinaAltered Forme    Ghost    Dragon    680  150     100
# 552  493                 Arceus   Normal         -    720  120     120
# 546  488              Cresselia  Psychic         -    600  120      70
# 543  486              Regigigas   Normal         -    670  110     160
# ..   ...                    ...      ...       ...    ...  ...     ...
# 264  245                Suicune    Water         -    580  100      75
# 553  494                Victini  Psychic      Fire    600  100     100
# 165  151                    Mew  Psychic         -    600  100     100
# 706  643               Reshiram   Dragon      Fire    680  100     120
# 707  644                 Zekrom   Dragon  Electric    680  100     150
#
#      Defense  SpAttack  SpDefense  Speed  Generation  Legendary
# ...

# %%
# Menampilkan Name dengan Elemen Rock dan Tipe Fairy Power diatas 300 dan Defense diatas 100
EDA[(EDA["Elemen"] == "Rock") & 
    (EDA["Tipe"] == "Fairy") &
    (EDA["Power"] >= 300)&
    (EDA["Defense"] >= 100)]
# Out:
#        #                 Name Elemen   Tipe  Power  HP  Attack  Defense  \
# 773  703              Carbink   Rock  Fairy    500  50      50      150
# 795  719              Diancie   Rock  Fairy    600  50     100      150
# 796  719  DiancieMega Diancie   Rock  Fairy    700  50     160      110
#
#      SpAttack  SpDefense  Speed  Generation  Legendary
# 773        50        150     50           6      False
# 795       100        150     50           6       True
# 796       160        110    110           6       True

# %%
# Menampilkan Name dengan Elemen Rock dan Tipe Fairy spesifik Power diatas 300, Defense diatas 100, SpDefense diatas 100 dan bukan tipe legendary
EDA[(EDA["Elemen"] == "Rock") & 
    (EDA["Tipe"] == "Fairy") &
    (EDA["Power"] >= 300)&
    (EDA["SpDefense"] >= 100)&
    (EDA["Defense"] >= 100)&
    (EDA["Legendary"] == False)
    ]
# Out:
#        #     Name Elemen   Tipe  Power  HP  Attack  Defense  SpAttack  \
# 773  703  Carbink   Rock  Fairy    500  50      50      150        50
#
#      SpDefense  Speed  Generation  Legendary
# 773        150     50           6      False

# %%
# Menampilkan Name dengan Elemen Rock dan Tipe Fairy spesifik Power diatas 300, Defense diatas 100, SpDefense diatas 100 dan tipe legendary
EDA[(EDA["Elemen"] == "Rock") & 
    (EDA["Tipe"] == "Fairy") &
    (EDA["Power"] >= 300)&
    (EDA["SpDefense"] >= 100)&
    (EDA["Defense"] >= 100)&
    (EDA["Legendary"] == True)
]
# Out:
#        #                 Name Elemen   Tipe  Power  HP  Attack  Defense  \
# 795  719              Diancie   Rock  Fairy    600  50     100      150
# 796  719  DiancieMega Diancie   Rock  Fairy    700  50     160      110
#
#      SpAttack  SpDefense  Speed  Generation  Legendary
# 795       100        150     50           6       True
# 796       160        110    110           6       True

# %%
EDA[(EDA["Name"].str.startswith("Dia")) & # .str.starswith digunakan untuk mencari kalimat yang dimulai
    (EDA["Elemen"] == "Rock") &
    (EDA["Legendary"] == False)]
# Out:
# Empty DataFrame
# Columns: [#, Name, Elemen, Tipe, Power, HP, Attack, Defense, SpAttack, SpDefense, Speed, Generation, Legendary]
# Index: []

# %%
EDA[(EDA["Name"].str.endswith("aur")) & # .str.endswith digunakan untuk mencari kalimat huruf yang terakhir
    (EDA["Elemen"] == "Grass") &
    (EDA["Legendary"] == False)]

# %% [markdown]
# ```txt
#    # Grouping and Aggregating
#    Langkah - langkah menggunakan Grouping and Aggregating pada dataset adalah mengelompokan data yang sesuai dengan kriteria yang diingikan
#
# ```

# %%
EDA["Elemen"].value_counts()

# %%
EDA["Tipe"].value_counts()

# %%
EDA.groupby(["Elemen", "Tipe"]).agg({"Defense": "max", "SpDefense":"max", "HP":"max"}).reset_index()

# %%
EDA.groupby(["Elemen", "Tipe"]).agg({"Defense": "min", "SpDefense":"m", "HP":"max"}).reset_index()

# %%
EDA[(EDA["Elemen"] == "Rock") & 
    (EDA["Tipe"] == "Fairy")
   ].groupby(["Name", "Defense"]).agg({"#":"count"}).reset_index() # Name dengan deffense terkuat Elemen Rock dan Fairy

# %%
# Menampilkan power tertinggi
EDA[(EDA["HP"] >= 100)&
    (EDA["Defense"] >= 100) &
   (EDA["SpDefense"] >= 100)&
   (EDA["Speed"] >= 100)
   ].groupby(["Name", "Generation"]).agg({"Power":"sum"}).sort_values("Power", ascending = False).reset_index()
# Out:
#                          Name  Generation  Power
# 0         MewtwoMega Mewtwo X           1    780
# 1       RayquazaMega Rayquaza           3    780
# 2                      Arceus           4    720
# 3                       Lugia           2    680
# 4                   Regigigas           4    670
# 5                      Celebi           2    600
# 6                     Jirachi           3    600
# 7                     Manaphy           4    600
# 8                         Mew           1    600
# 9           ShayminLand Forme           4    600
# 10                    Victini           5    600
# 11  KangaskhanMega Kangaskhan           1    590

# %%
EDA[(EDA["Elemen"] == "Rock")&
    (EDA["Tipe"] == "Fairy") & 
    (EDA["Legendary"] == False )
   ].groupby(["Name", "Elemen", "Tipe", "Generation"]).agg({"Defense": "sum", "SpDefense" :"sum"}).reset_index()  # Name dengan deffense terkuat Elemen Rock dan Fairy

# %% [markdown]
# ```txt
#   Pandas Visualitation
# ```

# %%
vis = df.copy()

# %%
#Menampilkan Defense Tertinggi Name dengan Combinasi Type
vis.groupby(['Type 1','Type 2'])['Defense'].max().sort_values(ascending = False).head(25).plot(kind = 'bar', figsize = (12, 5))
# Out:
# <AxesSubplot:xlabel='Type 1,Type 2'>

# %%
#Menampilkan kombinasi Type Name
visual=df.copy()
visual['Combination'] = (visual['Type 1'] + "+" + visual['Type 2'])
print(visual['Combination'].nunique())
visual["Combination"].value_counts().head(10).plot(kind="bar", figsize = (11, 5))
# Out:
# 136
# <AxesSubplot:>

# %%
plt.figure(figsize=(15,8)) #count of type 1 Name
sns.boxplot(x = vis['Generation'], y = vis['Total'])
plt.title('Pokemon types')
plt.show()

# %% [markdown]
# ## Conclusions, Assumptions, Overall Analysis
#
# ```txt
# -  Total Name yang memiliki kombinasi Defense terkuat terdapat pada Name Type "Steel + Ground dan Bug + Rock" disusul dengan Water + Psychiic dst
# -  Kombinasi Name Type terbanyak adalah tipe Normal + Flying
# -  Grafik persebaran total kekuatan dari setiap generasi memiliki nilai imbang dan signifikan yaitu range diantara 300 sampai 520
# -  Defense tertinggi Name legendary sebesar 200
# -  Defense terendah Name legendary sebesar 100
# -  Defense tertinggi Name non legendary sebesar 230
# -  Defense terendah Name non legendary sebesar 102
# ```
